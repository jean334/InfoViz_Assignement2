# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./Dataset/IRAhandle_tweets_1.csv", sep=",", header=None)
df2 = pd.read_csv("./Dataset/IRAhandle_tweets_2.csv", sep=",", header=None)
df3 = pd.read_csv("./Dataset/IRAhandle_tweets_3.csv", sep=",", header=None)
df4 = pd.read_csv("./Dataset/IRAhandle_tweets_4.csv", sep=",", header=None)
df5 = pd.read_csv("./Dataset/IRAhandle_tweets_5.csv", sep=",", header=None)
df6 = pd.read_csv("./Dataset/IRAhandle_tweets_6.csv", sep=",", header=None)
df7 = pd.read_csv("./Dataset/IRAhandle_tweets_7.csv", sep=",", header=None)
# Out:
# C:\Users\Jean\AppData\Local\Temp\ipykernel_60492\358566608.py:1: DtypeWarning: Columns (0,7,8,9,12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("./Dataset/IRAhandle_tweets_1.csv", sep=",", header=None)
# C:\Users\Jean\AppData\Local\Temp\ipykernel_60492\358566608.py:2: DtypeWarning: Columns (0,7,8,9,12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv("./Dataset/IRAhandle_tweets_2.csv", sep=",", header=None)
# C:\Users\Jean\AppData\Local\Temp\ipykernel_60492\358566608.py:3: DtypeWarning: Columns (0,7,8,9,12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv("./Dataset/IRAhandle_tweets_3.csv", sep=",", header=None)
# C:\Users\Jean\AppData\Local\Temp\ipykernel_60492\358566608.py:4: DtypeWarning: Columns (0,7,8,9,12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
print(df[13].unique())
# Out:
# ['account_category' 'RightTroll' 'NonEnglish' 'Fearmonger' 'LeftTroll'
#  'Unknown' 'HashtagGamer' 'NewsFeed' 'Commercial']

# %%
df_osef = pd.read_csv("./Dataset/IRAhandle_tweets_1.csv", sep=",", header=None)
df_osef
# Out:
# C:\Users\Jean\AppData\Local\Temp\ipykernel_60492\1257167942.py:1: DtypeWarning: Columns (0,7,8,9,12,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_osef = pd.read_csv("./Dataset/IRAhandle_tweets_1.csv", sep=",", header=None)
#                         0                1   \
# 0       external_author_id           author
# 1       906000000000000000           10_GOP
# 2       906000000000000000           10_GOP
# 3       906000000000000000           10_GOP
# 4       906000000000000000           10_GOP
# ...                    ...              ...
# 243887          2497991305  AUSTINLOVESBEER
# 243888          2497991305  AUSTINLOVESBEER
# 243889          2497991305  AUSTINLOVESBEER
# 243890          2497991305  AUSTINLOVESBEER
# 243891          2497991305  AUSTINLOVESBEER
#
#                                                        2              3   \
# 0                                                 content         region
# ...

# %%
indices1_1 = df[df[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices1_2 = df[df[13] == "LeftTroll"]
indices1_3 = df[df[13] == "Fearmonger"]
indices1_4 = df[df[13] == "NewsFeed"]
indices1_5 = df[df[13] == "Commercial"]
indices1_6 = df[df[13] == "HashtagGamer"]

indices2_1 = df2[df2[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices2_2 = df2[df2[13] == "LeftTroll"]
indices2_3 = df2[df2[13] == "Fearmonger"]
indices2_4 = df2[df2[13] == "NewsFeed"]
indices2_5 = df2[df2[13] == "Commercial"]
indices2_6 = df2[df2[13] == "HashtagGamer"]

indices3_1 = df3[df3[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices3_2 = df3[df3[13] == "LeftTroll"]
indices3_3 = df3[df3[13] == "Fearmonger"]
indices3_4 = df3[df3[13] == "NewsFeed"]
indices3_5 = df3[df3[13] == "Commercial"]
indices3_6 = df3[df3[13] == "HashtagGamer"]

indices4_1 = df4[df4[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices4_2 = df4[df4[13] == "LeftTroll"]
indices4_3 = df4[df4[13] == "Fearmonger"]
indices4_4 = df4[df4[13] == "NewsFeed"]
indices4_5 = df4[df4[13] == "Commercial"]
indices4_6 = df4[df4[13] == "HashtagGamer"]

indices5_1 = df5[df5[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices5_2 = df5[df5[13] == "LeftTroll"]
indices5_3 = df5[df5[13] == "Fearmonger"]
indices5_4 = df5[df5[13] == "NewsFeed"]
indices5_5 = df5[df5[13] == "Commercial"]
indices5_6 = df5[df5[13] == "HashtagGamer"]

indices6_1 = df6[df6[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices6_2 = df6[df6[13] == "LeftTroll"]
indices6_3 = df6[df6[13] == "Fearmonger"]
indices6_4 = df6[df6[13] == "NewsFeed"]
indices6_5 = df6[df6[13] == "Commercial"]
indices6_6 = df6[df6[13] == "HashtagGamer"]

indices7_1 = df7[df7[13] == "RightTroll"]# or df[13] == "LeftTroll" or df[13] == "Fearmonger"]
indices7_2 = df7[df7[13] == "LeftTroll"]
indices7_3 = df7[df7[13] == "Fearmonger"]
indices7_4 = df7[df7[13] == "NewsFeed"]
indices7_5 = df7[df7[13] == "Commercial"]
indices7_6 = df7[df7[13] == "HashtagGamer"]



df_filtered1 = pd.concat([indices1_1, indices1_2, indices1_3, indices1_4, indices1_5, indices1_6], ignore_index=True)
df_filtered2 = pd.concat([indices2_1, indices2_2, indices2_3, indices2_4, indices2_5, indices2_6], ignore_index=True)
df_filtered3 = pd.concat([indices3_1, indices3_2, indices3_3, indices3_4, indices3_5, indices3_6], ignore_index=True)
df_filtered4 = pd.concat([indices4_1, indices4_2, indices4_3, indices4_4, indices4_5, indices4_6], ignore_index=True)
df_filtered5 = pd.concat([indices5_1, indices5_2, indices5_3, indices5_4, indices5_5, indices5_6], ignore_index=True)
df_filtered6 = pd.concat([indices6_1, indices6_2, indices6_3, indices6_4, indices6_5, indices6_6], ignore_index=True)
df_filtered7 = pd.concat([indices7_1, indices7_2, indices7_3, indices7_4, indices7_5, indices7_6], ignore_index=True)

# %%
print(len(df_filtered1))
print(len(df))
# Out:
# 151266
# 243892

# %%
import matplotlib.pyplot as plt

df_filtered1["date"] = pd.to_datetime(df_filtered1[5], format="mixed")
df_filtered2["date"] = pd.to_datetime(df_filtered2[5], format="mixed")
df_filtered3["date"] = pd.to_datetime(df_filtered3[5], format="mixed")
df_filtered4["date"] = pd.to_datetime(df_filtered4[5], format="mixed")
df_filtered5["date"] = pd.to_datetime(df_filtered5[5], format="mixed")
df_filtered6["date"] = pd.to_datetime(df_filtered6[5], format="mixed")
df_filtered7["date"] = pd.to_datetime(df_filtered7[5], format="mixed")

# %%
df_filtered1["week"] = df_filtered1["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts1 = df_filtered1.groupby("week").size()

df_filtered2["week"] = df_filtered2["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts2 = df_filtered2.groupby("week").size()

df_filtered3["week"] = df_filtered3["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts3 = df_filtered3.groupby("week").size()

df_filtered4["week"] = df_filtered4["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts4 = df_filtered4.groupby("week").size()

df_filtered5["week"] = df_filtered5["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts5 = df_filtered5.groupby("week").size()

df_filtered6["week"] = df_filtered6["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts6 = df_filtered6.groupby("week").size()

df_filtered7["week"] = df_filtered7["date"].dt.strftime("%Y-%U")  # Format "YYYY-WW"
weekly_counts7 = df_filtered7.groupby("week").size()


"""
plt.figure(figsize=(12, 6))
weekly_counts.plot(kind="bar", color="steelblue")
plt.xlabel("Semaine")
plt.ylabel("Nombre d'entrées")
plt.title("Nombre d'entrées par semaine pour RightTroll")
plt.xticks(rotation=45)
plt.show() 
"""
# Out:
# '\nplt.figure(figsize=(12, 6))\nweekly_counts.plot(kind="bar", color="steelblue")\nplt.xlabel("Semaine")\nplt.ylabel("Nombre d\'entrées")\nplt.title("Nombre d\'entrées par semaine pour RightTroll")\nplt.xticks(rotation=45)\nplt.show() \n'

# %%
weekly_counts_global = pd.concat([weekly_counts1, weekly_counts2, weekly_counts3, weekly_counts4, weekly_counts5, weekly_counts6, weekly_counts7], axis=1)
weekly_counts_global
# Out:
#             0      1      2      3      4      5      6
# week
# 2014-47  72.0  342.0    NaN  438.0    NaN  194.0  690.0
# 2014-48  31.0  339.0    5.0  339.0    NaN   39.0  790.0
# 2014-49  38.0  116.0  117.0   47.0  109.0   69.0   80.0
# 2014-50   3.0  158.0  164.0   85.0    NaN  140.0   21.0
# 2014-51   2.0   92.0   53.0   71.0    1.0  143.0   91.0
# ...       ...    ...    ...    ...    ...    ...    ...
# 2018-16   NaN    NaN    NaN    NaN    NaN    NaN  107.0
# 2018-17   NaN    NaN    NaN    NaN    NaN    NaN  114.0
# 2018-18   NaN    NaN    NaN    NaN    NaN    NaN   94.0
# 2018-20   NaN    NaN    NaN    NaN    NaN    NaN   39.0
# 2018-21   NaN    NaN    NaN    NaN    NaN    NaN   15.0
#
# [235 rows x 7 columns]

# %%
#order by week 
weekly_counts_global = weekly_counts_global.sort_index()

# %%
weekly_counts_global_sum = weekly_counts_global.sum(axis=1)
#replace nan with 0
weekly_counts_global_sum = weekly_counts_global_sum.fillna(0)

# %%
weekly_counts_global_sum
df = pd.DataFrame(weekly_counts_global_sum)
df.to_csv("./assignement2-app/public/assets/hist4.csv", sep=",", index=True)
