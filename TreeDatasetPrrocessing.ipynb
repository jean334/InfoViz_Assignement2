# %% [markdown]
# # This notebook aims at preparing the data for tableau
#
# The intended visualization is a dual-axis bar and line chart. The bars represent the difference between consecutive five-year average Singapore temperatures, highlighting the fact that this difference tends to be positive—in other words, that Earth's temperature is consistently rising. The plot is inpsired by a famous plot of the GIEC (see project report)
#
# The line chart displays the average temperature over half-decades. The 0°C reference is omitted, as the focus is on temperature evolution rather than absolute values.

# %% [markdown]
# ## Importing the libraries

# %%
import json
from urllib.parse import unquote

# %% [markdown]
# ## Importing data from `categories.tsv`

# %%
groups = ["B_H_1500H", "B_H", "H"]

def createBranch(groups):
    if len(groups) == 1:
        return {"name": groups.pop(), "size": 1}
    while len(groups) > 0:
        sub_dict = {"name": groups.pop(), "children": [createBranch(groups)]}
    
    return sub_dict

sub_dict = createBranch(groups)
print(sub_dict)
# Out:
# {'name': 'H', 'children': [{'name': 'B_H', 'children': [{'name': 'B_H_1500H', 'size': 1}]}]}

# %%
def getSubGroups():
    all_subjects = []
    with open('Dataset/Wikipedia/wikispeedia_paths-and-graph/wikispeedia_paths-and-graph/categories.tsv', 'r') as f:
        line = f.readlines()

    for l in line:
        elem = l.split('\t')
        entry = elem[0]
        entry = unquote(entry)

        if len(elem) > 1:
            subjects = elem[1].split('.')
            subjects_list = []
            for s in subjects[1:]:
                if s[-1] == '\n':
                    s = s[:-1]
                subjects_list.append(s)
            all_subjects.append(subjects_list)

    return all_subjects

all_subjects = getSubGroups()

# %%
all_subjects
# Out:
# [['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Historical_figures'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['People', 'Artists'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Historical_figures'],
#  ['Business_Studies', 'Currency'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'Military_History_and_War'],
#  ['History', 'General_history'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['Everyday_life', 'Sports_events'],
#  ['History', 'General_history'],
#  ['Geography', 'Storms'],
#  ['History', 'Recent_History'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography', 'Natural_Disasters'],
#  ['History', 'General_history'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Geography', 'Natural_Disasters'],
#  ['Geography', 'Natural_Disasters'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography', 'Storms'],
#  ['History', 'Recent_History'],
#  ['Geography', 'Natural_Disasters'],
#  ['Geography', 'Natural_Disasters'],
#  ['Geography', 'Natural_Disasters'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['History', 'General_history'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'General_history'],
#  ['People', 'Sports_and_games_people'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Music', 'Performers_and_composers'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['History', 'Military_History_and_War'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['IT', 'Computing_hardware_and_infrastructure'],
#  ['Business_Studies', 'Companies'],
#  ['Science', 'Physics', 'General_Physics'],
#  ['Language_and_literature', 'Novels'],
#  ['Language_and_literature', 'Novels'],
#  ['Language_and_literature', 'Novels'],
#  ['Music', 'Musical_genres_styles_eras_and_events'],
#  ['Geography', 'European_Geography'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'European_Geography'],
#  ['Science', 'Biology', 'Plants'],
#  ['Everyday_life', 'Everyday_life'],
#  ['Mathematics'],
#  ['Geography', 'Geography_of_the_Middle_East'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['People', 'Historical_figures'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Language_and_literature', 'Theatre'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['People', 'Geographers_and_explorers'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Science', 'Physics', 'General_Physics'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Religion', 'Religious_texts'],
#  ['Geography', 'African_Geography'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['History', 'Military_History_and_War'],
#  ['People', 'Writers_and_critics'],
#  ['People', 'USA_Presidents'],
#  ['Everyday_life', 'Drink'],
#  ['Science', 'Physics', 'General_Physics'],
#  ['Art', 'Art'],
#  ['Countries'],
#  ['Geography', 'Geography_of_the_Middle_East', 'Middle_Eastern_Countries'],
#  ['Geography', 'African_Geography'],
#  ['Science', 'Physics', 'General_Physics'],
#  ['Business_Studies', 'Business'],
#  ['Geography', 'African_Geography'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Citizenship', 'Environment'],
#  ['Geography', 'General_Geography'],
#  ['Business_Studies', 'Companies'],
#  ['IT', 'Computing_hardware_and_infrastructure'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Language_and_literature', 'Theatre'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['Business_Studies', 'Economics'],
#  ['Business_Studies', 'Economics'],
#  ['People', 'Historical_figures'],
#  ['Geography', 'African_Geography'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['People', 'Religious_figures_and_leaders'],
#  ['People', 'Political_People'],
#  ['People', 'Historical_figures'],
#  ['Business_Studies', 'Business'],
#  ['Everyday_life', 'Everyday_life'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Geography', 'African_Geography'],
#  ['Language_and_literature', 'Literature_types'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'African_Geography'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['History', 'General_history'],
#  ['Language_and_literature', 'Languages'],
#  ['People', 'Historical_figures'],
#  ['Religion', 'Philosophy'],
#  ['IT', 'Websites_and_the_Internet'],
#  ['Religion', 'Philosophy'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['IT', 'Computer_Programming'],
#  ['People', 'Historical_figures'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['People', 'Historical_figures'],
#  ['People', 'Producers_directors_and_media_figures'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Geography', 'European_Geography'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Citizenship', 'Media'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['People', 'Mathematicians'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Science', 'Biology', 'Birds'],
#  ['People', 'Astronomers_and_physicists'],
#  ['People', 'Engineers_and_inventors'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['History', 'Pre_1900_Military'],
#  ['Religion', 'Religious_disputes'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['People', 'Mathematicians'],
#  ['People', 'Writers_and_critics'],
#  ['Science', 'Chemistry', 'General_Chemistry'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['People', 'Historical_figures'],
#  ['Science', 'Chemistry', 'General_Chemistry'],
#  ['People', 'Writers_and_critics'],
#  ['People', 'Military_People'],
#  ['People', 'Historical_figures'],
#  ['People', 'Engineers_and_inventors'],
#  ['People', 'Historical_figures'],
#  ['People', 'Military_People'],
#  ['People', 'Producers_directors_and_media_figures'],
#  ['People', 'Chemists'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Military_People'],
#  ['People', 'Monarchs_of_Great_Britain'],
#  ['Mathematics'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['History', 'Military_History_and_War'],
#  ['Geography', 'African_Geography'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Mathematics'],
#  ['Language_and_literature', 'Novels'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Music', 'Musical_Recordings_and_compositions'],
#  ['IT', 'Websites_and_the_Internet'],
#  ['Religion', 'Divinities'],
#  ['Religion', 'Religious_texts'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Language_and_literature', 'Poetry_and_Opera'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Language_and_literature', 'Linguistics'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Music', 'Musical_genres_styles_eras_and_events'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography', 'North_American_Geography'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'Mineralogy'],
#  ['People', 'Historical_figures'],
#  ['History', 'Pre_1900_Military'],
#  ['Language_and_literature', 'Languages'],
#  ['History', 'Pre_1900_Military'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Everyday_life', 'Sports'],
#  ['Music', 'Musical_genres_styles_eras_and_events'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Geography', 'Peoples'],
#  ['Geography', 'Mineralogy'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Geography', 'Mineralogy'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Geography', 'European_Geography'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Religion', 'Philosophy'],
#  ['Religion', 'Philosophy'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'General_history'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['People', 'Sports_and_games_people'],
#  ['People', 'Engineers_and_inventors'],
#  ['People', 'Political_People'],
#  ['People', 'Writers_and_critics'],
#  ['People', 'USA_Presidents'],
#  ['People', 'USA_Presidents'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['People', 'Artists'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography', 'African_Geography'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['Language_and_literature', 'Literature_types'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Citizenship', 'Animal_and_Human_Rights'],
#  ['Citizenship', 'Animal_and_Human_Rights'],
#  ['Everyday_life', 'Computer_and_Video_games'],
#  ['Everyday_life', 'Films'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Geography', 'North_American_Geography'],
#  ['Language_and_literature', 'Novels'],
#  ['People', 'Writers_and_critics'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['People', 'Monarchs_of_Great_Britain'],
#  ['People', 'Religious_figures_and_leaders'],
#  ['History', 'General_history'],
#  ['History', 'Recent_History'],
#  ['History', 'World_War_II'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Geography', 'African_Geography'],
#  ['Geography', 'Antarctica'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Geography', 'Antarctica'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['People', 'Artists'],
#  ['Geography', 'Peoples'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['People', 'Chemists'],
#  ['People', 'Performers_and_composers'],
#  ['People', 'Artists'],
#  ['People', 'Performers_and_composers'],
#  ['Geography', 'European_Geography'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Religion', 'Divinities'],
#  ['Science', 'Physics', 'Space_transport'],
#  ['Science', 'Physics', 'Space_transport'],
#  ['Religion', 'Religious_disputes'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Mathematics'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Everyday_life', 'Everyday_life'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Citizenship', 'Conflict_and_Peace'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Language_and_literature', 'Languages'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Language_and_literature', 'General_Literature'],
#  ['Geography', 'General_Geography'],
#  ['Language_and_literature', 'Theatre'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['History', 'Archaeology'],
#  ['Science', 'Biology', 'Birds'],
#  ['People', 'Religious_figures_and_leaders'],
#  ['People', 'Mathematicians'],
#  ['Design_and_Technology', 'Architecture'],
#  ['IT', 'Software'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Geography', 'General_Geography'],
#  ['Geography', 'General_Geography'],
#  ['Music', 'Performers_and_composers'],
#  ['Geography', 'General_Geography'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['People', 'Political_People'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['People', 'Philosophers'],
#  ['Mathematics'],
#  ['Science', 'Biology', 'Mammals'],
#  ['People', 'Historical_figures'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['People', 'Political_People'],
#  ['People', 'Producers_directors_and_media_figures'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['History', 'General_history'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Art', 'Art'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['People', 'Military_People'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['People', 'Writers_and_critics'],
#  ['People', 'Writers_and_critics'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['People', 'Military_People'],
#  ['Art', 'Art'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Everyday_life', 'Recreation'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['History', 'Historians_chroniclers_and_history_books'],
#  ['People', 'Human_Scientists'],
#  ['Religion', 'Philosophy'],
#  ['Religion', 'Divinities'],
#  ['Geography', 'European_Geography'],
#  ['Everyday_life', 'Sports'],
#  ['Geography', 'North_American_Geography'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Geography', 'General_Geography'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['Religion', 'Myths'],
#  ['Science', 'Chemistry', 'General_Chemistry'],
#  ['Music', 'Musical_genres_styles_eras_and_events'],
#  ['History', 'World_War_II'],
#  ['People', 'Historical_figures'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['People', 'Historical_figures'],
#  ['People', 'Military_People'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Language_and_literature', 'Theatre'],
#  ['People', 'Writers_and_critics'],
#  ['Language_and_literature', 'Literature_types'],
#  ['People', 'Artists'],
#  ['People', 'Religious_figures_and_leaders'],
#  ['People', 'Historical_figures'],
#  ['Countries'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Language_and_literature', 'Languages'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Everyday_life', 'Sports_events'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Everyday_life', 'Sports'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Everyday_life', 'Sports'],
#  ['Science', 'Biology', 'Plants'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Design_and_Technology', 'Road_transport'],
#  ['Design_and_Technology', 'Road_transport'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Geography', 'Climate_and_the_Weather'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Geography', 'Natural_Disasters'],
#  ['Everyday_life', 'Television'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['History', 'World_War_II'],
#  ['Design_and_Technology', 'Engineering'],
#  ['People', 'Political_People'],
#  ['Science', 'Biology', 'Mammals'],
#  ['People', 'Historical_figures'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Geography', 'Peoples'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Business_Studies', 'Companies'],
#  ['IT', 'Computer_Programming'],
#  ['Citizenship', 'Media'],
#  ['Everyday_life', 'Television'],
#  ['Everyday_life', 'Television'],
#  ['Business_Studies', 'Companies'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['People', 'Sports_and_games_people'],
#  ['Science', 'Biology', 'Mammals'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['People', 'Historical_figures'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Everyday_life', 'Games'],
#  ['Science', 'Biology', 'Organisms'],
#  ['Citizenship', 'Community_organisations'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Everyday_life', 'Sports'],
#  ['Everyday_life', 'Games'],
#  ['Geography', 'Geography_of_the_Middle_East'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Countries'],
#  ['Geography', 'Geography_of_the_Middle_East', 'Middle_Eastern_Countries'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'General_Geography'],
#  ['Geography', 'North_American_Geography'],
#  ['Geography', 'African_Geography'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Geography', 'African_Geography'],
#  ['Business_Studies', 'Companies'],
#  ['Business_Studies', 'Currency'],
#  ['People', 'Artists'],
#  ['Geography', 'African_Geography'],
#  ['People', 'Political_People'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['People', 'Human_Scientists'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'European_Geography'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Organisms'],
#  ['Art', 'Art'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['People', 'Philosophers'],
#  ['Everyday_life', 'Sports'],
#  ['Geography', 'European_Geography'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Everyday_life', 'Television'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Everyday_life', 'Sports'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Music', 'Musical_Instruments'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['History', 'Recent_History'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Everyday_life', 'Cartoons'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'Military_History_and_War'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'British_History', 'British_History_Post_1900'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'World_War_II'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'Pre_1900_Military'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['History', 'Military_History_and_War'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'World_War_II'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'World_War_II'],
#  ['History', 'World_War_II'],
#  ['History', 'World_War_II'],
#  ['History', 'World_War_II'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'World_War_II'],
#  ['History', 'World_War_II'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'Military_History_and_War'],
#  ['History', 'World_War_II'],
#  ['History', 'World_War_II'],
#  ['History', 'Pre_1900_Military'],
#  ['History', 'World_War_II'],
#  ['History', 'Military_History_and_War'],
#  ['History', 'Military_History_and_War'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Geography', 'General_Geography'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Music', 'Musical_Recordings_and_compositions'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['History', 'Historians_chroniclers_and_history_books'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Everyday_life', 'Recreation'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Everyday_life', 'Drink'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Business_Studies', 'Economics'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Geography', 'Geography_of_the_Middle_East'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Design_and_Technology', 'Architecture'],
#  ['Everyday_life', 'Films'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['People', 'Writers_and_critics'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Language_and_literature', 'Languages'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['People', 'Political_People'],
#  ['History', 'World_War_II'],
#  ['People', 'Performers_and_composers'],
#  ['Language_and_literature', 'Poetry_and_Opera'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['People', 'Political_People'],
#  ['People', 'Astronomers_and_physicists'],
#  ['People', 'Historical_figures'],
#  ['People', 'USA_Presidents'],
#  ['Design_and_Technology', 'Architecture'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['History', 'Historians_chroniclers_and_history_books'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Language_and_literature', 'Languages'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Geography', 'European_Geography'],
#  ['History', 'Recent_History'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['People', 'Sports_and_games_people'],
#  ['People', 'Philosophers'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Religion', 'Religious_texts'],
#  ['Design_and_Technology', 'Road_transport'],
#  ['Everyday_life', 'Films'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['People', 'Political_People'],
#  ['People', 'Computing_People'],
#  ['People', 'Performers_and_composers'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Citizenship', 'Environment'],
#  ['Citizenship', 'Environment'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Citizenship', 'Environment'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['IT', 'Software'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Everyday_life', 'Films'],
#  ['Geography', 'Climate_and_the_Weather'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'African_Geography'],
#  ['People', 'Sports_and_games_people'],
#  ['Geography', 'European_Geography'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Birds'],
#  ['History', 'General_history'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'General_Geography'],
#  ['Geography', 'Peoples'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Birds'],
#  ['Everyday_life', 'Games'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Everyday_life', 'Films'],
#  ['People', 'Mathematicians'],
#  ['History', 'World_War_II'],
#  ['Everyday_life', 'Games'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Birds'],
#  ['Everyday_life', 'Television'],
#  ['Science', 'Biology', 'Birds'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Music', 'Musical_genres_styles_eras_and_events'],
#  ['Science', 'Physics', 'Electricity_and_Electronics'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Everyday_life', 'Games'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['People', 'Performers_and_composers'],
#  ['People', 'Performers_and_composers'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['History', 'British_History', 'British_History_Post_1900'],
#  ['Everyday_life', 'Sports_events'],
#  ['Design_and_Technology', 'Air_and_Sea_transport'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Music', 'Musical_Recordings_and_compositions'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Geography', 'European_Geography'],
#  ['Geography', 'European_Geography'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Birds'],
#  ['Language_and_literature', 'Literature_types'],
#  ['Religion', 'Religious_texts'],
#  ['Language_and_literature', 'General_Literature'],
#  ['Mathematics'],
#  ['Science', 'Biology', 'Plants'],
#  ['People', 'Sports_and_games_people'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Geography', 'North_American_Geography'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Science', 'Biology', 'Mammals'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Historical_figures'],
#  ['Geography', 'North_American_Geography'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Geography', 'Antarctica'],
#  ['Science', 'Biology', 'Organisms'],
#  ['Citizenship', 'Community_organisations'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['People', 'Historical_figures'],
#  ['People', 'Political_People'],
#  ['Language_and_literature', 'Languages'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Religion', 'Divinities'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Music', 'Musical_Instruments'],
#  ['Geography', 'European_Geography'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['People', 'Historical_figures'],
#  ['Business_Studies', 'Economics'],
#  ['People', 'Sports_and_games_people'],
#  ['Design_and_Technology', 'Engineering'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['Business_Studies', 'Companies'],
#  ['History', 'British_History'],
#  ['Language_and_literature', 'Languages'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['History', 'British_History'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Citizenship', 'Politics_and_government'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['Citizenship', 'Media'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['History', 'Ancient_History_Classical_History_and_Mythology'],
#  ['People', 'Writers_and_critics'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['People', 'Performers_and_composers'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Art', 'Art'],
#  ['Geography', 'European_Geography'],
#  ['IT', 'Cryptography'],
#  ['Geography', 'North_American_Geography'],
#  ['IT', 'Software'],
#  ['Geography', 'European_Geography'],
#  ['Design_and_Technology', 'Architecture'],
#  ['People', 'Engineers_and_inventors'],
#  ['Geography', 'European_Geography'],
#  ['People', 'Religious_figures_and_leaders'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Art', 'Art'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Everyday_life', 'Television'],
#  ['Countries'],
#  ['Geography', 'European_Geography', 'European_Countries'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Business_Studies', 'Business'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Design_and_Technology', 'Engineering'],
#  ['History', 'General_history'],
#  ['IT', 'Computer_Programming'],
#  ['People', 'Writers_and_critics'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['People', 'Writers_and_critics'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['IT', 'Computing_hardware_and_infrastructure'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['IT', 'Cryptography'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['People', 'Engineers_and_inventors'],
#  ['Geography', 'African_Geography'],
#  ['Geography', 'Geography_of_the_Middle_East'],
#  ['Geography', 'Mineralogy'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Mathematics'],
#  ['Geography', 'North_American_Geography'],
#  ['Geography', 'North_American_Geography'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Art', 'Art'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['People', 'USA_Presidents'],
#  ['Everyday_life', 'Cartoons'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Geography', 'Geography_of_Asia', 'Asian_Countries'],
#  ['Countries'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Countries'],
#  ['Geography', 'North_American_Geography'],
#  ['Science', 'Biology', 'Birds'],
#  ['Citizenship', 'Law'],
#  ['Language_and_literature', 'Languages'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Everyday_life', 'Sports'],
#  ['Design_and_Technology', 'Engineering'],
#  ['People', 'Artists'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Insects_Reptiles_and_Fish'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Design_and_Technology', 'Architecture'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Monarchs_of_Great_Britain'],
#  ['Science', 'Physics', 'Electricity_and_Electronics'],
#  ['Science', 'Physics', 'Space_transport'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Geography', 'African_Geography'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Citizenship', 'Politics_and_government'],
#  ['Religion', 'Divinities'],
#  ['Everyday_life', 'Cartoons'],
#  ['Geography', 'Central_and_South_American_Geography'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['People', 'Historical_figures'],
#  ['People', 'Artists'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Science', 'Chemistry', 'Chemical_compounds'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Science', 'Biology', 'Organisms'],
#  ['Everyday_life', 'Games'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'General_Geography'],
#  ['People', 'Mathematicians'],
#  ['People', 'Historical_figures'],
#  ['People', 'Human_Scientists'],
#  ['People', 'Sports_and_games_people'],
#  ['People', 'Astronomers_and_physicists'],
#  ['Geography', 'North_American_Geography'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Geography', 'Geography_of_Oceania_Australasia'],
#  ['History', 'Historians_chroniclers_and_history_books'],
#  ['People', 'Human_Scientists'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Everyday_life', 'Films'],
#  ['Science', 'Physics', 'General_Physics'],
#  ['Geography', 'General_Geography'],
#  ['Science', 'Physics', 'Space_transport'],
#  ['Science', 'Biology', 'Birds'],
#  ['Design_and_Technology', 'Architecture'],
#  ['History',
#   'British_History',
#   'British_History_1500_and_before_including_Roman_Britain'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['People', 'Performers_and_composers'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['Design_and_Technology', 'Architecture'],
#  ['History', 'British_History', 'British_History_Post_1900'],
#  ['People', 'Historical_figures'],
#  ['Religion', 'Religious_movements_traditions_and_organizations'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Geography', 'Geology_and_geophysics'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ['Countries'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['People', 'Performers_and_composers'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Music', 'Musical_Instruments'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Everyday_life', 'Sports'],
#  ['Religion', 'Myths'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['IT', 'Computing_hardware_and_infrastructure'],
#  ['Science', 'Biology', 'Dinosaurs'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Plants'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Science', 'Physics', 'Space_Astronomy'],
#  ['Science', 'Chemistry', 'Chemical_elements'],
#  ['Geography', 'African_Geography', 'African_Countries'],
#  ['Countries'],
#  ['Citizenship', 'Conflict_and_Peace'],
#  ['History', 'Recent_History'],
#  ['Science', 'Biology', 'Birds'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['People', 'Historical_figures'],
#  ['People', 'Computing_People'],
#  ['People', 'Human_Scientists'],
#  ['People', 'Writers_and_critics'],
#  ['People', 'Writers_and_critics'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['People', 'Monarchs_of_Great_Britain'],
#  ['History', 'British_History', 'British_History_15001750'],
#  ['People', 'Monarchs_of_Great_Britain'],
#  ['People', 'Historical_figures'],
#  ['People', 'Historical_figures'],
#  ['People', 'Actors_models_and_celebrities'],
#  ['Language_and_literature', 'Novels'],
#  ['History', 'British_History', 'British_History_17501900'],
#  ['People', 'Historical_figures'],
#  ['Everyday_life', 'Television'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Mammals'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Science', 'Chemistry', 'General_Chemistry'],
#  ['Science', 'Biology', 'General_Biology'],
#  ['Science', 'Chemistry', 'General_Chemistry'],
#  ['Geography', 'Geography_of_Asia'],
#  ['Design_and_Technology', 'Engineering'],
#  ['History', 'Recent_History'],
#  ['Everyday_life', 'Games'],
#  ['People', 'USA_Presidents'],
#  ['Science', 'Biology', 'Plants'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'Geography_of_Great_Britain'],
#  ['Geography', 'North_American_Geography'],
#  ['Everyday_life', 'Sports_teams'],
#  ['Design_and_Technology', 'Railway_transport'],
#  ['Everyday_life', 'Food_and_agriculture'],
#  ['Science', 'Biology', 'Health_and_medicine'],
#  ['History', 'Military_History_and_War'],
#  ['Religion', 'Religious_disputes'],
#  ['Citizenship', 'Animal_and_Human_Rights'],
#  ['Geography',
#   'Central_and_South_American_Geography',
#   'Central_and_South_American_Countries'],
#  ...]

# %%
def insert_branch(root, branch):
    """ Insère une branche dans l'arbre """
    node = root
    for i, name in enumerate(branch):
        # Vérifier si le nœud existe déjà
        if "children" in node:
            found = next((child for child in node["children"] if child["name"] == name), None)
        
        if found:
            node = found
        else:
            # Si on est à la feuille, on ajoute "size"
            new_node = {"name": name}
            if i == len(branch) - 1:
                new_node["size"] = 1  # Peut être ajusté selon les besoins
            else:
                new_node["children"] = []
            node["children"].append(new_node)
            node = new_node

def build_tree(branches):
    """ Construit un arbre à partir d'une liste de branches """
    root = {"name": "root", "children": []}  # Racine virtuelle
    for branch in branches:
        insert_branch(root, branch)
    return root

# Exemple de données
branches = [
    ["History", "British_History", "British_History_1500_and_before_including_Roman_Britain"],
    ["History", "European_History", "French_Revolution"],
    ["History", "British_History", "Modern_British_History"]
]

# Construction de l'arbre
tree = build_tree(all_subjects)

# Suppression de la racine virtuelle si besoin
if len(tree["children"]) == 1:
    tree = tree["children"][0]

# Sauvegarde en JSON
with open("./D3Viz/netviz/src/assets/Tree.json", "w", encoding="utf-8") as f:
    json.dump(tree, f, indent=4)

print(json.dumps(tree, indent=4))
# Out:
# {
#     "name": "root",
#     "children": [
#         {
#             "name": "History",
#             "children": [
#                 {
#                     "name": "British_History",
#                     "children": [
#                         {
#                             "name": "British_History_1500_and_before_including_Roman_Britain",
#                             "size": 1
#                         },
#                         {
#                             "name": "British_History_15001750",
#                             "size": 1
#                         },
#                         {
#                             "name": "British_History_17501900",
#                             "size": 1
#                         },
#                         {
#                             "name": "British_History_Post_1900",
#                             "size": 1
#                         }
#                     ]
#                 },
#                 {
#                     "name": "General_history",
#                     "size": 1
#                 },
#                 {
#                     "name": "Military_History_and_War",
#                     "size": 1
#                 },
#                 {
#                     "name": "Recent_History",
#                     "size": 1
#                 },
#                 {
#                     "name": "Ancient_History_Classical_History_and_Mythology",
#                     "size": 1
#                 },
#                 {
#                     "name": "Pre_1900_Military",
#                     "size": 1
#                 },
#                 {
#                     "name": "World_War_II",
#                     "size": 1
#                 },
#                 {
#                     "name": "Archaeology",
#                     "size": 1
#                 },
#                 {
#                     "name": "Historians_chroniclers_and_history_books",
#                     "size": 1
#                 },
#                 {
#                     "name": "North_American_History",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "People",
#             "children": [
#                 {
#                     "name": "Historical_figures",
#                     "size": 1
#                 },
#                 {
#                     "name": "Artists",
#                     "size": 1
#                 },
#                 {
#                     "name": "Sports_and_games_people",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geographers_and_explorers",
#                     "size": 1
#                 },
#                 {
#                     "name": "Writers_and_critics",
#                     "size": 1
#                 },
#                 {
#                     "name": "USA_Presidents",
#                     "size": 1
#                 },
#                 {
#                     "name": "Religious_figures_and_leaders",
#                     "size": 1
#                 },
#                 {
#                     "name": "Political_People",
#                     "size": 1
#                 },
#                 {
#                     "name": "Producers_directors_and_media_figures",
#                     "size": 1
#                 },
#                 {
#                     "name": "Mathematicians",
#                     "size": 1
#                 },
#                 {
#                     "name": "Astronomers_and_physicists",
#                     "size": 1
#                 },
#                 {
#                     "name": "Engineers_and_inventors",
#                     "size": 1
#                 },
#                 {
#                     "name": "Military_People",
#                     "size": 1
#                 },
#                 {
#                     "name": "Chemists",
#                     "size": 1
#                 },
#                 {
#                     "name": "Monarchs_of_Great_Britain",
#                     "size": 1
#                 },
#                 {
#                     "name": "Actors_models_and_celebrities",
#                     "size": 1
#                 },
#                 {
#                     "name": "Performers_and_composers",
#                     "size": 1
#                 },
#                 {
#                     "name": "Philosophers",
#                     "size": 1
#                 },
#                 {
#                     "name": "Human_Scientists",
#                     "size": 1
#                 },
#                 {
#                     "name": "Computing_People",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Countries",
#             "size": 1
#         },
#         {
#             "name": "Geography",
#             "children": [
#                 {
#                     "name": "European_Geography",
#                     "children": [
#                         {
#                             "name": "European_Countries",
#                             "size": 1
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Storms",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geology_and_geophysics",
#                     "size": 1
#                 },
#                 {
#                     "name": "Natural_Disasters",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geography_of_the_Middle_East",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geography_of_Great_Britain",
#                     "size": 1
#                 },
#                 {
#                     "name": "African_Geography",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geography_of_Asia",
#                     "children": [
#                         {
#                             "name": "Asian_Countries",
#                             "size": 1
#                         }
#                     ]
#                 },
#                 {
#                     "name": "General_Geography",
#                     "size": 1
#                 },
#                 {
#                     "name": "Geography_of_Oceania_Australasia",
#                     "size": 1
#                 },
#                 {
#                     "name": "North_American_Geography",
#                     "size": 1
#                 },
#                 {
#                     "name": "Central_and_South_American_Geography",
#                     "size": 1
#                 },
#                 {
#                     "name": "Mineralogy",
#                     "size": 1
#                 },
#                 {
#                     "name": "Peoples",
#                     "size": 1
#                 },
#                 {
#                     "name": "Antarctica",
#                     "size": 1
#                 },
#                 {
#                     "name": "Climate_and_the_Weather",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Business_Studies",
#             "children": [
#                 {
#                     "name": "Currency",
#                     "size": 1
#                 },
#                 {
#                     "name": "Companies",
#                     "size": 1
#                 },
#                 {
#                     "name": "Business",
#                     "size": 1
#                 },
#                 {
#                     "name": "Economics",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Science",
#             "children": [
#                 {
#                     "name": "Physics",
#                     "children": [
#                         {
#                             "name": "Space_Astronomy",
#                             "size": 1
#                         },
#                         {
#                             "name": "General_Physics",
#                             "size": 1
#                         },
#                         {
#                             "name": "Space_transport",
#                             "size": 1
#                         },
#                         {
#                             "name": "Electricity_and_Electronics",
#                             "size": 1
#                         },
#                         {
#                             "name": "The_Planets",
#                             "size": 1
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Biology",
#                     "children": [
#                         {
#                             "name": "Health_and_medicine",
#                             "size": 1
#                         },
#                         {
#                             "name": "Mammals",
#                             "size": 1
#                         },
#                         {
#                             "name": "Plants",
#                             "size": 1
#                         },
#                         {
#                             "name": "General_Biology",
#                             "size": 1
#                         },
#                         {
#                             "name": "Birds",
#                             "size": 1
#                         },
#                         {
#                             "name": "Insects_Reptiles_and_Fish",
#                             "size": 1
#                         },
#                         {
#                             "name": "Dinosaurs",
#                             "size": 1
#                         },
#                         {
#                             "name": "Organisms",
#                             "size": 1
#                         },
#                         {
#                             "name": "Evolution_and_reproduction",
#                             "size": 1
#                         }
#                     ]
#                 },
#                 {
#                     "name": "Chemistry",
#                     "children": [
#                         {
#                             "name": "Chemical_compounds",
#                             "size": 1
#                         },
#                         {
#                             "name": "Chemical_elements",
#                             "size": 1
#                         },
#                         {
#                             "name": "General_Chemistry",
#                             "size": 1
#                         },
#                         {
#                             "name": "Materials_science",
#                             "size": 1
#                         }
#                     ]
#                 }
#             ]
#         },
#         {
#             "name": "Everyday_life",
#             "children": [
#                 {
#                     "name": "Sports_events",
#                     "size": 1
#                 },
#                 {
#                     "name": "Everyday_life",
#                     "size": 1
#                 },
#                 {
#                     "name": "Drink",
#                     "size": 1
#                 },
#                 {
#                     "name": "Food_and_agriculture",
#                     "size": 1
#                 },
#                 {
#                     "name": "Sports_teams",
#                     "size": 1
#                 },
#                 {
#                     "name": "Sports",
#                     "size": 1
#                 },
#                 {
#                     "name": "Computer_and_Video_games",
#                     "size": 1
#                 },
#                 {
#                     "name": "Films",
#                     "size": 1
#                 },
#                 {
#                     "name": "Recreation",
#                     "size": 1
#                 },
#                 {
#                     "name": "Television",
#                     "size": 1
#                 },
#                 {
#                     "name": "Games",
#                     "size": 1
#                 },
#                 {
#                     "name": "Cartoons",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Design_and_Technology",
#             "children": [
#                 {
#                     "name": "Railway_transport",
#                     "size": 1
#                 },
#                 {
#                     "name": "Air_and_Sea_transport",
#                     "size": 1
#                 },
#                 {
#                     "name": "Engineering",
#                     "size": 1
#                 },
#                 {
#                     "name": "Architecture",
#                     "size": 1
#                 },
#                 {
#                     "name": "Road_transport",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Music",
#             "children": [
#                 {
#                     "name": "Performers_and_composers",
#                     "size": 1
#                 },
#                 {
#                     "name": "Musical_genres_styles_eras_and_events",
#                     "size": 1
#                 },
#                 {
#                     "name": "Musical_Recordings_and_compositions",
#                     "size": 1
#                 },
#                 {
#                     "name": "Musical_Instruments",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "IT",
#             "children": [
#                 {
#                     "name": "Computing_hardware_and_infrastructure",
#                     "size": 1
#                 },
#                 {
#                     "name": "Websites_and_the_Internet",
#                     "size": 1
#                 },
#                 {
#                     "name": "Computer_Programming",
#                     "size": 1
#                 },
#                 {
#                     "name": "Software",
#                     "size": 1
#                 },
#                 {
#                     "name": "Cryptography",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Language_and_literature",
#             "children": [
#                 {
#                     "name": "Novels",
#                     "size": 1
#                 },
#                 {
#                     "name": "Theatre",
#                     "size": 1
#                 },
#                 {
#                     "name": "Literature_types",
#                     "size": 1
#                 },
#                 {
#                     "name": "Languages",
#                     "size": 1
#                 },
#                 {
#                     "name": "Poetry_and_Opera",
#                     "size": 1
#                 },
#                 {
#                     "name": "Linguistics",
#                     "size": 1
#                 },
#                 {
#                     "name": "General_Literature",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Mathematics",
#             "size": 1
#         },
#         {
#             "name": "Religion",
#             "children": [
#                 {
#                     "name": "Religious_movements_traditions_and_organizations",
#                     "size": 1
#                 },
#                 {
#                     "name": "Religious_texts",
#                     "size": 1
#                 },
#                 {
#                     "name": "Philosophy",
#                     "size": 1
#                 },
#                 {
#                     "name": "Religious_disputes",
#                     "size": 1
#                 },
#                 {
#                     "name": "Divinities",
#                     "size": 1
#                 },
#                 {
#                     "name": "Myths",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Art",
#             "children": [
#                 {
#                     "name": "Art",
#                     "size": 1
#                 },
#                 {
#                     "name": "Artists",
#                     "size": 1
#                 }
#             ]
#         },
#         {
#             "name": "Citizenship",
#             "children": [
#                 {
#                     "name": "Environment",
#                     "size": 1
#                 },
#                 {
#                     "name": "Politics_and_government",
#                     "size": 1
#                 },
#                 {
#                     "name": "Media",
#                     "size": 1
#                 },
#                 {
#                     "name": "Animal_and_Human_Rights",
#                     "size": 1
#                 },
#                 {
#                     "name": "Conflict_and_Peace",
#                     "size": 1
#                 },
#                 {
#                     "name": "Community_organisations",
#                     "size": 1
#                 },
#                 {
#                     "name": "Law",
#                     "size": 1
#                 },
#                 {
#                     "name": "Culture_and_Diversity",
#                     "size": 1
#                 },
#                 {
#                     "name": "Education",
#                     "size": 1
#                 }
#             ]
#         }
#     ]
# }

# %%
import copy
all_subjects_copy = copy.deepcopy(all_subjects)

def compareBranchLength(b1, b2):
    return b1["size"] - b2["size"] > 0



def fuseDicts(d):
    nb_cat = 1
    id = d[0]["name"]
    cat = {id:{"name": id, "index": 0, "branch": copy.deepcopy(d[0])}}

    for i,elem in enumerate(d[1:]):
        if elem["name"] == id:
            for child in elem["children"]:
                d[0]["children"].append(child)
        
        elif elem["name"] not in cat.keys():
            nb_cat += 1
            cat[elem["name"]] = {"name": elem["name"], "index": i+1, "branch": copy.deepcopy(elem)}
        
        elif compareBranchLength(elem, cat[id]["branch"]):
            cat[id]["branch"] = elem
            cat[id]["index"] = i+1

    index_list = []
    for name in cat.keys():
        ind = cat[name]["index"]   
        index_list.append(ind)
        if "children" in d[ind]:
            for i,elem in enumerate(d[ind:]):
                if elem["name"] == name:
                    for child in elem["children"]:
                        d[ind]["children"].append(child)



    all_1 = [copy.deepcopy(d[i]) for i in index_list]
    return all_1

all_1 = fuseDicts(all_subjects_copy["children"])
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[101], line 44
#      41     all_1 = [copy.deepcopy(d[i]) for i in index_list]
#      42     return all_1
# ---> 44 all_1 = fuseDicts(all_subjects_copy["children"])
#
# Cell In[101], line 37, in fuseDicts(d)
#      35             if elem["name"] == name:
#      36                 for child in elem["children"]:
# ---> 37                     d[ind]["children"].append(child)
#      41 all_1 = [copy.deepcopy(d[i]) for i in index_list]
#      42 return all_1
#
# MemoryError:

# %%
all_1
# Out:
# [{'name': 'History',
#   'children': [{'name': 'British_History',
#     'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#       'size': 1}]},
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'North_American_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [...],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Archaeology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Pre_1900_Military', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'World_War_II', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'British_History', 'size': 1}],
#    [{'name': 'Ancient_History_Classical_History_and_Mythology', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'Historians_chroniclers_and_history_books', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_Post_1900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_15001750', 'size': 1}]}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_17501900', 'size': 1}]}],
#    [{'name': 'Recent_History', 'size': 1}],
#    [{'name': 'Military_History_and_War', 'size': 1}],
#    [{'name': 'General_history', 'size': 1}],
#    [{'name': 'British_History',
#      'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain',
#        'size': 1}]}],
#    [{'name': 'North_American_History', 'size': 1}],
# ...
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Religious_disputes', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Philosophy', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Religious_texts', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Myths', 'size': 1}],
#    [{'name': 'Divinities', 'size': 1}],
#    [{'name': 'Religious_movements_traditions_and_organizations', 'size': 1}]],
#   'size': 2},
#  {'name': 'Art',
#   'children': [{'name': 'Art', 'size': 1},
#    [...],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Artists', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Artists', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}],
#    [{'name': 'Art', 'size': 1}]],
#   'size': 2},
#  {'name': 'Citizenship',
#   'children': [{'name': 'Environment', 'size': 1},
#    [...],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Culture_and_Diversity', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Law', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Education', 'size': 1}],
#    [{'name': 'Media', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Conflict_and_Peace', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Politics_and_government', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}],
#    [{'name': 'Animal_and_Human_Rights', 'size': 1}],
#    [{'name': 'Community_organisations', 'size': 1}],
#    [{'name': 'Environment', 'size': 1}]],
#   'size': 2}]

# %%
for i in range(10):
    print(all_1[0]["children"][i])
# Out:
# {'name': 'British_History', 'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain', 'size': 1}]}
# [{'name': 'British_History', 'children': [{'name': 'British_History_1500_and_before_including_Roman_Britain', 'size': 1}]}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'Military_History_and_War', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
# [{'name': 'General_history', 'size': 1}]
